# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data
#
# Download the [Stock Market Dataset from Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset). Note that you may be required to register for a free account.
#
# Extract all files into the directory: `./05_src/data/prices_csv/`
#
# Your folder structure should include the following paths:
#
# + `05_src/data/prices_csv/etfs`
# + `05_src/data/prices_csv/stocks`

# %%
import pandas as pd
import os
import sys
from glob import glob

sys.path.append(os.getenv('SRC_DIR'))

from utils.logger import get_logger
_logs = get_logger(__name__)

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to load the historical price data for stocks and ETFs, we could use:

# %%
import random
# glob act as a search for the file/s ..
stock_files = glob(os.path.join(os.getenv('SRC_DIR'), "data/prices_csv/stocks/*.csv"))

random.seed(42)
stock_files = random.sample(stock_files, 60)

dt_list = []
for s_file in stock_files:
    _logs.info(f"Reading file: {s_file}")
    dt = pd.read_csv(s_file).assign(
        source = os.path.basename(s_file),
        ticker = os.path.basename(s_file).replace('.csv', ''),
        Date = lambda x: pd.to_datetime(x['Date'])
    )
    dt_list.append(dt)
stock_prices = pd.concat(dt_list, axis = 0, ignore_index = True)

# %%
dt_list[0]
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     1973-02-22   4.250000   4.250000   4.250000   4.250000   0.507389
# 1     1973-02-23   4.250000   4.250000   4.250000   4.250000   0.507389
# 2     1973-02-26   4.250000   4.250000   4.250000   4.250000   0.507389
# 3     1973-02-27   4.250000   4.250000   4.250000   4.250000   0.507389
# 4     1973-02-28   4.250000   4.250000   4.250000   4.250000   0.507389
# ...          ...        ...        ...        ...        ...        ...
# 11878 2020-03-26  54.060001  57.869999  54.060001  57.610001  57.610001
# 11879 2020-03-27  55.000000  55.369999  52.320000  53.450001  53.450001
# 11880 2020-03-30  53.810001  58.240002  53.180000  58.020000  58.020000
# 11881 2020-03-31  57.270000  59.790001  55.880001  57.950001  57.950001
# 11882 2020-04-01  55.139999  55.139999  51.110001  51.919998  51.919998
#
#        Volume   source ticker
# 0         800  TNC.csv    TNC
# 1         800  TNC.csv    TNC
# 2         800  TNC.csv    TNC
# 3           0  TNC.csv    TNC
# 4           0  TNC.csv    TNC
# ...       ...      ...    ...
# 11878  103300  TNC.csv    TNC
# 11879   72800  TNC.csv    TNC
# 11880   92200  TNC.csv    TNC
# 11881  136700  TNC.csv    TNC
# 11882   86500  TNC.csv    TNC
#
# [11883 rows x 9 columns]

# %%
print(type(stock_prices))
stock_prices.head(4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#         Date  Open  High   Low  Close  Adj Close  Volume   source ticker
# 0 1973-02-22  4.25  4.25  4.25   4.25   0.507389   800.0  TNC.csv    TNC
# 1 1973-02-23  4.25  4.25  4.25   4.25   0.507389   800.0  TNC.csv    TNC
# 2 1973-02-26  4.25  4.25  4.25   4.25   0.507389   800.0  TNC.csv    TNC
# 3 1973-02-27  4.25  4.25  4.25   4.25   0.507389     0.0  TNC.csv    TNC

# %%
#os.getenv('SRC_DIR')
glob(os.path.join(os.getenv('SRC_DIR'), "data/prices_csv/stocks/*.csv"))

# %% [markdown]
# Verify the structure of the `stock_prices` data:

# %%
s_file = stock_files[0]
dt = pd.read_csv(s_file).assign(
    source = os.path.basename(s_file),
    ticker = os.path.basename(s_file).replace('.csv',''),
    date = lambda x: pd.to_datetime(x['Date'])
)
dt.head()
# Out:
#          Date  Open  High   Low  Close  Adj Close  Volume   source ticker  \
# 0  1973-02-22  4.25  4.25  4.25   4.25   0.507389     800  TNC.csv    TNC
# 1  1973-02-23  4.25  4.25  4.25   4.25   0.507389     800  TNC.csv    TNC
# 2  1973-02-26  4.25  4.25  4.25   4.25   0.507389     800  TNC.csv    TNC
# 3  1973-02-27  4.25  4.25  4.25   4.25   0.507389       0  TNC.csv    TNC
# 4  1973-02-28  4.25  4.25  4.25   4.25   0.507389       0  TNC.csv    TNC
#
#         date
# 0 1973-02-22
# 1 1973-02-23
# 2 1973-02-26
# 3 1973-02-27
# 4 1973-02-28

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. A good reference for this type of data manipulation is Panda's [Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data) and [Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %%
select_tickers = stock_prices['ticker'].unique().tolist()
select_tickers

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time
import shutil

# %%
temp = os.getenv("TEMP_DATA")
csv_dir = os.path.join(temp, "csv")
shutil.rmtree(csv_dir, ignore_errors=True)

# %%
stock_csv = os.path.join(csv_dir, "stock_px.csv")
print(stock_csv)
print(csv_dir)
os.makedirs(csv_dir, exist_ok=True)
# Out:
# ../../05_src/data/temp/csv\stock_px.csv
# ../../05_src/data/temp/csv

# %%
print(temp)
# Out:
# ../../05_src/data/temp/

# %%
start = time.time()
stock_prices.to_csv(stock_csv, index = False)
end = time.time()

_logs.info(f'Writing data ({stock_prices.shape}) to csv took {end - start} seconds.')
_logs.info(f'CSV file size { os.path.getsize(stock_csv)*1e-6 } MB')
# Out:
# 2025-09-26 16:32:58,557, 473192941.py, 5, INFO, Writing data ((239659, 9)) to csv took 1.6148097515106201 seconds.
# 2025-09-26 16:32:58,558, 473192941.py, 6, INFO, CSV file size 26.618403999999998 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
#!pip install --upgrade dask pyarrow fastparquet pandas

# %%
import dask.dataframe as dd

parquet_dir = os.path.join(temp, "parquet")
shutil.rmtree(parquet_dir, ignore_errors=True)
print(parquet_dir)
os.makedirs(parquet_dir, exist_ok=True)
# Out:
# ../../05_src/data/temp/parquet

# %%
px_dd = dd.from_pandas(stock_prices, npartitions = len(select_tickers))

start = time.time()
px_dd.to_parquet(parquet_dir, engine = "pyarrow")
end = time.time()

_logs.info(f'Writing dd ({stock_prices.shape}) to parquet took {end - start} seconds.')
_logs.info(f'Parquet file size { get_dir_size(parquet_dir)*1e-6 } MB')
# Out:
# 2025-09-26 16:51:54,285, 817812245.py, 7, INFO, Writing dd ((239659, 9)) to parquet took 0.39217638969421387 seconds.
# 2025-09-26 16:51:54,288, 817812245.py, 8, INFO, Parquet file size 9.718058 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to large joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
stock_prices.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'source',
#        'ticker'],
#       dtype='object')

# %%
for ticker in stock_prices['ticker'].unique():
    ticker_dt = stock_prices[stock_prices['ticker'] == ticker]
    ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
    for yr in ticker_dt['Year'].unique():
        yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dd.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "**/*.parquet"), recursive = True)
dd_px = dd.read_parquet(parquet_files).set_index("ticker")

# %%
dd_px
# Out:
# Dask DataFrame Structure:
#                           Date     Open     High      Low    Close Adj Close   Volume  source   Year
# npartitions=60
# ACN             datetime64[ns]  float64  float64  float64  float64   float64  float64  string  int32
# ALDX                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# ...                        ...      ...      ...      ...      ...       ...      ...     ...    ...
# ZIXI                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# ZIXI                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# Dask Name: sort_index, 8 graph layers

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
stock_prices
# Out:
#              Date   Open   High    Low  Close  Adj Close      Volume   source  \
# 0      1973-02-22   4.25   4.25   4.25   4.25   0.507389       800.0  TNC.csv
# 1      1973-02-23   4.25   4.25   4.25   4.25   0.507389       800.0  TNC.csv
# 2      1973-02-26   4.25   4.25   4.25   4.25   0.507389       800.0  TNC.csv
# 3      1973-02-27   4.25   4.25   4.25   4.25   0.507389         0.0  TNC.csv
# 4      1973-02-28   4.25   4.25   4.25   4.25   0.507389         0.0  TNC.csv
# ...           ...    ...    ...    ...    ...        ...         ...      ...
# 239654 2020-03-26   9.97  11.59   9.65  11.46  11.460000  22494500.0  KEY.csv
# 239655 2020-03-27  10.72  11.69  10.70  11.20  11.200000  20794800.0  KEY.csv
# 239656 2020-03-30  11.04  11.24  10.38  10.79  10.790000  15175400.0  KEY.csv
# 239657 2020-03-31  10.68  10.86  10.12  10.37  10.370000  15997000.0  KEY.csv
# 239658 2020-04-01   9.63   9.72   9.35   9.45   9.450000  14533700.0  KEY.csv
#
#        ticker
# 0         TNC
# 1         TNC
# 2         TNC
# 3         TNC
# 4         TNC
# ...       ...
# 239654    KEY
# 239655    KEY
# 239656    KEY
# 239657    KEY
# 239658    KEY
#
# [239659 rows x 9 columns]

# %%
dd_shift = dd_px.groupby('ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
)
# Out:
# C:\Users\Suha\AppData\Local\Temp\ipykernel_27056\102405636.py:1: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_shift = dd_px.groupby('ticker', group_keys=False).apply(

# %%
dd_rets = dd_shift.assign(
    Returns = lambda x: x['Close']/x['Close_lag_1'] - 1
)

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                           Date     Open     High      Low    Close Adj Close   Volume  source   Year Close_lag_1  Returns
# npartitions=60
# ACN             datetime64[ns]  float64  float64  float64  float64   float64  float64  string  int32     float64  float64
# ALDX                       ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# ...                        ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# ZIXI                       ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# ZIXI                       ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# Dask Name: assign, 14 graph layers

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# ticker
# ACN    2018-01-02  153.500000  154.100006  152.779999  153.839996  148.655960
# ACN    2018-01-03  152.990005  154.990005  152.990005  154.550003  149.342056
# ACN    2018-01-04  155.000000  156.860001  154.770004  156.380005  151.110382
# ACN    2018-01-05  156.610001  157.720001  156.130005  157.669998  152.356918
# ACN    2018-01-08  157.369995  159.009995  156.839996  158.929993  153.574463
# ...           ...         ...         ...         ...         ...         ...
# ZIXI   2003-06-26    4.040000    4.190000    3.860000    4.000000    4.000000
# ZIXI   2003-06-27    4.000000    4.050000    3.790000    3.850000    3.850000
# ZIXI   2003-06-30    3.840000    4.000000    3.720000    3.770000    3.770000
# ZIXI   2003-07-01    3.720000    3.850000    3.650000    3.780000    3.780000
# ZIXI   2003-07-02    3.810000    3.990000    3.730000    3.730000    3.730000
#
#            Volume    source  Year  Close_lag_1   Returns
# ticker
# ACN     3061900.0   ACN.csv  2018          NaN       NaN
# ACN     2064200.0   ACN.csv  2018   153.839996  0.004615
# ACN     1777000.0   ACN.csv  2018   154.550003  0.011841
# ACN     1597600.0   ACN.csv  2018   156.380005  0.008249
# ACN     2616900.0   ACN.csv  2018   157.669998  0.007991
# ...           ...       ...   ...          ...       ...
# ZIXI     515300.0  ZIXI.csv  2003     4.040000 -0.009901
# ZIXI     162400.0  ZIXI.csv  2003     4.000000 -0.037500
# ZIXI     119900.0  ZIXI.csv  2003     3.850000 -0.020779
# ZIXI     202100.0  ZIXI.csv  2003     3.770000  0.002653
# ZIXI      81100.0  ZIXI.csv  2003     3.780000 -0.013228
#
# [239659 rows x 11 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before save
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)
dd_rets.to_parquet(FEATURES_DATA, overwrite = True)

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/stock_prices/data_manager.py`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %%
from stock_prices.data_manager import DataManager
dm = DataManager()

# %% [markdown]
# Download all prices.

# %%
dm.process_sample_files()
# Out:
# 2025-09-26 20:21:43,219, data_manager.py, 53, INFO, Processing sample of tickers
# 2025-09-26 20:21:43,220, data_manager.py, 64, INFO, Getting file list from ../../05_src/data/prices_csv/
# 2025-09-26 20:21:43,261, data_manager.py, 66, INFO, Found 8050 files in ../../05_src/data/prices/
# 2025-09-26 20:21:43,262, data_manager.py, 74, INFO, Selecting sample of files
# 2025-09-26 20:21:43,263, data_manager.py, 80, INFO, Selected 30 files
# 2025-09-26 20:21:43,264, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\ARE.csv
# 2025-09-26 20:21:43,264, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\ARE.csv
# 2025-09-26 20:21:43,290, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:44,030, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\TRIL.csv
# 2025-09-26 20:21:44,031, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\TRIL.csv
# 2025-09-26 20:21:44,051, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:44,283, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\CLSD.csv
# 2025-09-26 20:21:44,284, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\CLSD.csv
# 2025-09-26 20:21:44,299, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:44,447, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\SYBX.csv
# 2025-09-26 20:21:44,448, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\SYBX.csv
# 2025-09-26 20:21:44,467, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:44,642, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\BCBP.csv
# 2025-09-26 20:21:44,643, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\BCBP.csv
# 2025-09-26 20:21:44,666, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:45,301, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\MMAC.csv
# 2025-09-26 20:21:45,301, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\MMAC.csv
# 2025-09-26 20:21:45,330, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:46,108, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\XFLT.csv
# 2025-09-26 20:21:46,109, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\XFLT.csv
# 2025-09-26 20:21:46,122, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:46,240, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\BXS.csv
# 2025-09-26 20:21:46,242, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\BXS.csv
# 2025-09-26 20:21:46,270, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:47,365, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\TRTX.csv
# 2025-09-26 20:21:47,367, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\TRTX.csv
# 2025-09-26 20:21:47,382, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:47,514, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\EXLS.csv
# 2025-09-26 20:21:47,515, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\EXLS.csv
# 2025-09-26 20:21:47,538, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:48,051, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\etfs\XBI.csv
# 2025-09-26 20:21:48,052, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\etfs\XBI.csv
# 2025-09-26 20:21:48,075, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:48,542, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\BGSF.csv
# 2025-09-26 20:21:48,543, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\BGSF.csv
# 2025-09-26 20:21:48,561, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:48,779, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\WEX.csv
# 2025-09-26 20:21:48,780, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\WEX.csv
# 2025-09-26 20:21:48,804, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:49,284, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\THQ.csv
# 2025-09-26 20:21:49,285, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\THQ.csv
# 2025-09-26 20:21:49,301, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:49,504, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\AACG.csv
# 2025-09-26 20:21:49,504, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\AACG.csv
# 2025-09-26 20:21:49,517, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:49,578, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\XOM.csv
# 2025-09-26 20:21:49,579, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\XOM.csv
# 2025-09-26 20:21:49,611, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:51,459, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\etfs\RFDI.csv
# 2025-09-26 20:21:51,460, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\etfs\RFDI.csv
# 2025-09-26 20:21:51,481, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:51,630, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\AKBA.csv
# 2025-09-26 20:21:51,631, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\AKBA.csv
# 2025-09-26 20:21:51,647, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:51,893, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\etfs\DIVA.csv
# 2025-09-26 20:21:51,893, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\etfs\DIVA.csv
# 2025-09-26 20:21:51,910, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:52,081, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\KWR.csv
# 2025-09-26 20:21:52,081, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\KWR.csv
# 2025-09-26 20:21:52,109, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:53,352, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\TMP.csv
# 2025-09-26 20:21:53,353, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\TMP.csv
# 2025-09-26 20:21:53,379, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:54,401, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\RGEN.csv
# 2025-09-26 20:21:54,402, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\RGEN.csv
# 2025-09-26 20:21:54,435, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:55,637, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\HMHC.csv
# 2025-09-26 20:21:55,637, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\HMHC.csv
# 2025-09-26 20:21:55,654, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:55,989, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\BOMN.csv
# 2025-09-26 20:21:55,990, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\BOMN.csv
# 2025-09-26 20:21:56,004, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:56,150, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\etfs\MUNI.csv
# 2025-09-26 20:21:56,151, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\etfs\MUNI.csv
# 2025-09-26 20:21:56,195, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:56,530, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\ADP.csv
# 2025-09-26 20:21:56,532, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\ADP.csv
# 2025-09-26 20:21:56,561, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:57,714, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\etfs\IAU.csv
# 2025-09-26 20:21:57,714, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\etfs\IAU.csv
# 2025-09-26 20:21:57,738, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:58,206, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\SMMT.csv
# 2025-09-26 20:21:58,207, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\SMMT.csv
# 2025-09-26 20:21:58,224, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:58,400, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\ANIX.csv
# 2025-09-26 20:21:58,401, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\ANIX.csv
# 2025-09-26 20:21:58,427, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 20:21:59,615, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\etfs\FDIS.csv
# 2025-09-26 20:21:59,616, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\etfs\FDIS.csv
# 2025-09-26 20:21:59,632, data_manager.py, 101, INFO, Saving data by year

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2025-09-26 20:22:04,988, data_manager.py, 131, INFO, Creating features data.
# 2025-09-26 20:22:04,989, data_manager.py, 141, INFO, Loading price data from ../../05_src/data/prices/
# 2025-09-26 20:22:33,057, data_manager.py, 150, INFO, Creating features
# c:\Users\Suha\Desktop\Suha\DSI\production\01_materials\labs\../../05_src\stock_prices\data_manager.py:153: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   features = (price_dd.groupby('ticker', group_keys=False)
# 2025-09-26 20:22:33,065, data_manager.py, 175, INFO, Saving features to ../../05_src/data/features/stock_features
